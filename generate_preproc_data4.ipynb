# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 1.5 MB/s
# Requirement already satisfied: nltk>=3.1 in ./.local/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in ./.local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.8.17)
# Requirement already satisfied: click in /opt/tljh/user/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.1.3)
# Requirement already satisfied: tqdm in /opt/tljh/user/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: joblib in ./.local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import time
from textblob import TextBlob

# %%
train = pd.read_csv("Source/x_train.csv")

# %%
# train

# %%
m = 800
df_train = train[m:m+200]
pd.options.mode.chained_assignment = None

# %%
def reverse_translit_2(word):
    i = 0
    lenght = len(word)
    new_word = ""
    while(i < lenght):
        symbol = word[i]
        if symbol == "a":
            new_word += "а"

        elif symbol == "b":
            new_word += "б"

        elif symbol == "v":
            new_word += "в"

        elif symbol == "g":
            new_word += "г"
        
        elif symbol == "h":
            new_word += "х"

        elif symbol == "d":
            new_word += "д"

        elif symbol == "e":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "э"
                i += 1
            else:
                new_word += "е"

        elif symbol == "y":
            if (i + 1) < lenght and word[i + 1] == "a":
                new_word += "я"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "u":
                new_word += "ю"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ь"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "o":
                new_word += "ё"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "e":
                new_word += "е"
                i += 1
            else:
                new_word += "й"
            if (i + 2) < lenght and word[i + 1] == word[i + 2] == "h":
                new_word += "ъ"
                i += 2

        elif symbol == "z":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ж"
                i += 1
            else:
                new_word += "з"

        elif symbol == "i":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ы"
                i += 1
            else:
                new_word += "и"

        elif symbol == "k":
            new_word += "к"

        elif symbol == "l":
            new_word += "л"

        elif symbol == "m":
            new_word += "м"

        elif symbol == "n":
            new_word += "н"

        elif symbol == "o":
            new_word += "о"

        elif symbol == "p":
            new_word += "п"

        elif symbol == "r":
            new_word += "р"

        elif symbol == "s":
            if (i + 1) < lenght and word[i + 1] == "h":
                if (i + 2) < lenght and word[i + 2] == "h":
                    new_word += "щ"
                    i += 2
                else:
                    new_word += "ш"
                    i += 1
            else:
                    new_word += "с"

        elif symbol == "t":
            new_word += "т"

        elif symbol == "u":
            new_word += "у"

        elif symbol == "f":
            new_word += "ф"

        elif symbol == "c":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ч"
                i += 1
            else:
                new_word += "ц"

        i += 1
    return(new_word)

# %%
df_train_len = len(df_train)
s = time.perf_counter()
for j in range(m, df_train_len + m):
    if type(df_train["tokens"][j]) != float:
        train_without_translit = df_train["tokens"][j].split()
        ll = len(train_without_translit)
        for i in range(0, ll, 2):
            # print(type(train_without_translit[i][0]))
            if 97 <= ord(train_without_translit[i][0]) <= 122:
                textBlb = TextBlob(train_without_translit[i])
                textCorrected = textBlb.correct()
                if textCorrected == textBlb:
                    pass
                else:
                    train_without_translit[i] = reverse_translit_2(train_without_translit[i])
            # print(i)
            current_word = train_without_translit[i]
            current_len = len(current_word)
            current_del = int(np.floor(current_len * 0.2))
            # print(current_word, ' ', current_len, ' ', current_del)
            if current_del >= 1:
                train_without_translit[i] = train_without_translit[i][0: - current_del]
        df_train['tokens'][j] = train_without_translit
    print(j, ' ', (time.perf_counter() - s) / 60)
    print(train_without_translit[i])
# Out:
# 800   0.254109104200082
# рэпа
# 801   1.2783491491000556
# зени
# 802   1.2813855135334355
# услуг
# 803   1.90527224831676
# зимне
# 804   1.9411511663667624
# докто
# 805   2.0468316784167353
# объе
# 806   2.0511080338500807
# темнот
# 807   2.0883583352000037
# kontakt
# 808   2.7520557079167096
# porazhae
# 809   2.7552908862333423
# туториа
# 810   2.897738631833393
# бюджетны
# 811   2.9084739313500902
# бытово
# 812   2.908490402100021
# securit
# 813   3.5529717008834267
# тысяч
# 814   3.5556606016833636
# карт
# 815   3.7560464129001048
# ответ
# 816   3.7591882899834066
# машин
# 817   3.8665455291500015
# externa
# 818   4.511326226116702
# song
# 819   4.5113285521000455
# song
# 820   6.063801943616757
# сканирован
# 821   6.479700533150026
# ветеран
# 822   6.753047404766766
# time
# 823   6.757831737333375
# октябрьск
# 824   6.769189289600035
# оформле
# 825   7.689446505400095
# клас
# 826   8.911944831116731
# аним
# 827   9.469227900783396
# song
# 828   9.554803814450013
# персональн
# 829   9.578767366683435
# журна
# 830   9.739919114183431
# decisio
# 831   10.38507083200008
# banner
# 832   10.392798889150072
# рсс
# 833   11.38812703291672
# song
# 834   11.500205924500067
# наличны
# 835   12.47453863423337
# аним
# 836   12.604707364616722
# троы
# 837   12.877107691416677
# rasskaza
# 838   12.88552410020008
# card
# 839   12.88553262013338
# мазь
# 840   13.056663023416695
# лини
# 841   13.10218042501668
# фильмо
# 842   13.884832664800099
# отправлен
# 843   14.002216767616725
# отправленн
# 844   14.950472796866718
# щенк
# 845   15.078631420833336
# banner
# 846   15.787648931983373
# сини
# 847   15.809519904316767
# банк
# 848   15.884440176050097
# devochk
# 849   16.160264702933393
# ищу
# 850   16.166183224116686
# банк
# 851   16.392896603016684
# срок
# 852   16.58641000435006
# banner
# 853   17.155064690833388
# актрисо
# 854   17.78384034786674
# gosdum
# 855   17.94437014995007
# akademij
# 856   18.082086957583428
# ангстре
# 857   18.0820997953501
# отправленн
# 858   18.3198575150834
# spokoyno
# 859   18.39523439521666
# официально
# 860   18.43232392418334
# недвижимос
# 861   19.296014011666678
# лини
# 862   19.691712477933347
# sosedk
# 863   19.69172084285007
# почт
# 864   19.907275885833347
# мине
# 865   20.06669181160008
# бессмертно
# 866   20.455369001983367
# эпиляци
# 956   61.07745095263344
# губерние
# 957   61.083330208299955
# land
# 958   61.11319796176674
# material
# 959   61.17426491990009
# оплатит
# 960   63.02499371759998
# rep
# 961   63.025008144466725
# love
# 962   63.164635762116696
# молни
# 963   63.60179211910011
# noutbuk
# 964   63.827134808833335
# аним
# 965   64.49120906464995
# kontakt
# 966   64.63615334076664
# канакин
# 967   64.66530262471679
# аптек
# 968   66.91938843110002
# андрои
# 969   67.54627426948342
# adul
# 970   67.66461115235009
# наличны
# 971   67.6698651060667
# banner
# 972   67.71368136898346
# бага
# 973   68.03562166651669
# чери
# 974   71.83798063723334
# урал
# 975   72.24821830670007
# регламен
# 976   74.09485337851669
# андрои
# 977   74.10554367928331
# музык
# 978   74.20583071965
# заявк
# 979   75.19013051183343
# novink
# 980   78.8026525651334
# повод
# 981   82.83361622816678
# gosdum
# 982   83.79777901156667
# участник
# 983   84.42675647950006
# дубл
# 984   84.42676763391682
# календар

# %%
df_train.to_csv("Source/df_train_short_800_1000.csv", index = False)

# %%
train_ex = pd.read_csv("Source/df_train_short_800_1000.csv")

# %%
train_ex
# Out:
#      Unnamed: 0  CLIENT_ID  RETRO_DT  \
# 0           800    5588847  20200522
# 1           801    1202046  20210327
# 2           802    6112924  20201112
# 3           803    1105999  20210304
# 4           804    1485818  20210610
# ..          ...        ...       ...
# 195         995    5187188  20200215
# 196         996    5167950  20200210
# 197         997  811119351  20210924
# 198         998    5605493  20200527
# 199         999    5468926  20200419
#
#                                                 tokens  \
# 0    ['limite', '1', 'снят', '1', 'яблок', '1', 'ун...
# 1    ['деньг', '2', 'расхо', '1', 'такс', '1', 'выи...
# 2    ['алла', '1', 'временно', '2', 'мужа', '2', 'у...
# 3    ['платиз', '1', 'серг', '1', 'code', '1', 'отк...
# 4    ['купит', '2', 'владельц', '1', 'сезо', '11', ...
# ..                                                 ...
# 195  ['знал', '1', 'серг', '1', 'сторон', '1', 'ста...
# 196                                      ['почт', '2']
# 197  ['инач', '1', 'выплат', '1', 'домодедо', '1', ...
# 198  ['креди', '4', 'offic', '1', 'mone', '1', 'вйш...
# 199  ['дист', '2', 'udali', '1', 'плать', '2', 'реа...
#
#                                            urls_hashed
# 0    d8877075c359034c6cb8b9ce2b1748a3 14 275732ef4d...
# 1    aee71c8d18d6b91b36bf599208a91777 2 15ba9c76ab1...
# 2    47ac64d915aea230cec3089daca73d63 1 484cff20658...
# 3    aee71c8d18d6b91b36bf599208a91777 26 cd2c78c8b8...
# 4    d8877075c359034c6cb8b9ce2b1748a3 12 aee71c8d18...
# ..                                                 ...
# 195  df2034af8d2187b92ef77da28871860e 3 1a06c2a842f...
# 196  7405aaece8dbd9b744b0752a7ecae526 2 197d57e77f6...
# 197  9efb7d411e002e8313f82ae2f79d51aa 1 a3f05ccaba8...
# 198  37402b251bf0f324ede703fb82ff912c 1 4e3e482c0e1...
# 199  03c459245ad0bda6f0c833ae5e2454e1 1 038ef314e02...
#
# [200 rows x 5 columns]

# %%
d = None
