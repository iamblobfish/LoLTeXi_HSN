# %%
import numpy as np
import pandas as pd
# from nltk.stem.snowball import SnowballStemmer
# import pymorphy2
import time
from textblob import TextBlob
df_train_short_1400 = pd.read_csv("Source/df_train_short_1400.csv")
df_train_short_1400_1600 = pd.read_csv("Source/df_train_short_1400_1600.csv")

# %%
df_train_short_1400_1600
# Out:
#      Unnamed: 0  CLIENT_ID  RETRO_DT  \
# 0          1400    5949459  20200926
# 1          1401    1124059  20210309
# 2          1402    1903651  20210922
# 3          1403    1482263  20210609
# 4          1404    1123935  20210309
# ..          ...        ...       ...
# 195        1595    1807042  20210826
# 196        1596  811869491  20211012
# 197        1597    5868610  20200829
# 198        1598    5280045  20200307
# 199        1599    5475864  20200421
#
#                                                 tokens  \
# 0    ['smartfon', '3', 'креди', '2', 'работ', '1', ...
# 1    ['ради', '2', 'серге', '1', 'сторон', '1', 'оп...
# 2    ['выплат', '1', 'отказо', '3', 'forge', '2', '...
# 3    ['креди', '2', 'банковск', '1', 'новы', '2', '...
# 4    ['входящи', '1', 'recover', '1', 'почт', '1', ...
# ..                                                 ...
# 195                                     ['задач', '4']
# 196  ['звонкам', '2', 'мобильны', '4', 'снят', '2',...
# ...

# %%
df_train_short_1600 = pd.concat([df_train_short_1400, df_train_short_1400_1600], axis = 0)

# %%
df_train_short_1600
# Out:
#      Unnamed: 0  CLIENT_ID  RETRO_DT  \
# 0             0    5909886  20200911
# 1             1    1385448  20210519
# 2             2    1866195  20210913
# 3             3    1587081  20210702
# 4             4    1400908  20210522
# ..          ...        ...       ...
# 195        1595    1807042  20210826
# 196        1596  811869491  20211012
# 197        1597    5868610  20200829
# 198        1598    5280045  20200307
# 199        1599    5475864  20200421
#
#                                                 tokens  \
# 0    ['форм', '1', 'мачех', '1', 'работ', '1', 'пас...
# 1    ['платиз', '1', 'мобильны', '2', 'серг', '1', ...
# 2    ['симс', '3', 'креди', '1', 'язык', '1', 'разл...
# 3    ['code', '1', 'истори', '1', 'сцф', '1', 'шаг'...
# 4    ['отказо', '2', 'товар', '1', 'серге', '1', 'к...
# ..                                                 ...
# 195                                     ['задач', '4']
# 196  ['звонкам', '2', 'мобильны', '4', 'снят', '2',...
# ...

# %%
df_train_short_1600.to_csv("Source/df_train_short_1600.csv", index = False)
