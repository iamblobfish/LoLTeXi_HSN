# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 1.5 MB/s
# Requirement already satisfied: nltk>=3.1 in ./.local/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in ./.local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.8.17)
# Requirement already satisfied: click in /opt/tljh/user/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.1.3)
# Requirement already satisfied: tqdm in /opt/tljh/user/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: joblib in ./.local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import time
from textblob import TextBlob

# %%
train = pd.read_csv("Source/x_train.csv")

# %%
train
# Out:
#         Unnamed: 0  CLIENT_ID  RETRO_DT  \
# 0                0    5909886  20200911
# 1                1    1385448  20210519
# 2                2    1866195  20210913
# 3                3    1587081  20210702
# 4                4    1400908  20210522
# ...            ...        ...       ...
# 303772      303772    6220063  20201211
# 303773      303773    5543361  20200507
# 303774      303774  224227891  20211218
# 303775      303775    5909478  20200911
# 303776      303776    5536683  20200506
#
#                                                    tokens  \
# 0       форм 1 мачеха 1 работы 1 пасынка 1 горячую 1 м...
# 1       platiza 1 мобильные 2 sergej 1 code 3 отказов ...
# 2       sims 3 кредит 1 языке 1 разлива 1 огромное 1 о...
# 3       code 1 историй 1 scf 1 шаг 1 деньги 3 серый 1 ...
# 4       отказов 2 tovara 1 сергея 1 купальный 1 чёрный...
# ...                                                   ...
# 303772  морковь 1 вред 1 описание 1 калорийность 1 пол...
# 303773  мотылёк 1 uploader 1 photo 1 провокатор 2 смс ...
# 303774  чёрный 1 деньги 12 бытовой 1 серый 3 маршрутов...
# 303775  kabelya 1 pesen 2 статья 2 опубликовала 1 купи...
# 303776  smartfony 1 шины 4 итак 1 ипотеку 1 сергею 1 с...
#
#                                               urls_hashed
# 0       7bbcc146c0ba4df814701ff7297b2205 1 ee0d49cbc99...
# 1       1889e0cbd3e343e9521a07aa312257ac 2 8253d8d3a67...
# 2       6e617b4bfdbef85d8b09ec08ac72f0f2 1 94309f5f116...
# 3       1e833434273e04ba76cfcfb4b48ad21b 3 aee71c8d18d...
# 4       83e85bee0d81c0e9e5047e202cddf534 3 6e617b4bfdb...
# ...                                                   ...
# 303772  2c45709d8e05171bfb39b7528e97ac5f 1 0028c3b6811...
# 303773  30d2c325f9f511359a476c67e1130ef5 2 18394875e74...
# 303774  e7f1dd5dbad8f9535e775b21bb0b9173 1 a4dba6829fa...
# 303775  ccbbab80c3bf2d7533e2ca1baed78073 1 503c50cb580...
# 303776  3889d372c1b472a980a9225bc746672a 1 c11f2dc2461...
#
# [303777 rows x 5 columns]

# %%
m = 1200
df_train = train[m:m+200]
pd.options.mode.chained_assignment = None

# %%
def reverse_translit_2(word):
    i = 0
    lenght = len(word)
    new_word = ""
    while(i < lenght):
        symbol = word[i]
        if symbol == "a":
            new_word += "а"

        elif symbol == "b":
            new_word += "б"

        elif symbol == "v":
            new_word += "в"

        elif symbol == "g":
            new_word += "г"
        
        elif symbol == "h":
            new_word += "х"

        elif symbol == "d":
            new_word += "д"

        elif symbol == "e":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "э"
                i += 1
            else:
                new_word += "е"

        elif symbol == "y":
            if (i + 1) < lenght and word[i + 1] == "a":
                new_word += "я"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "u":
                new_word += "ю"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ь"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "o":
                new_word += "ё"
                i += 1
            elif (i + 1) < lenght and word[i + 1] == "e":
                new_word += "е"
                i += 1
            else:
                new_word += "й"
            if (i + 2) < lenght and word[i + 1] == word[i + 2] == "h":
                new_word += "ъ"
                i += 2

        elif symbol == "z":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ж"
                i += 1
            else:
                new_word += "з"

        elif symbol == "i":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ы"
                i += 1
            else:
                new_word += "и"

        elif symbol == "k":
            new_word += "к"

        elif symbol == "l":
            new_word += "л"

        elif symbol == "m":
            new_word += "м"

        elif symbol == "n":
            new_word += "н"

        elif symbol == "o":
            new_word += "о"

        elif symbol == "p":
            new_word += "п"

        elif symbol == "r":
            new_word += "р"

        elif symbol == "s":
            if (i + 1) < lenght and word[i + 1] == "h":
                if (i + 2) < lenght and word[i + 2] == "h":
                    new_word += "щ"
                    i += 2
                else:
                    new_word += "ш"
                    i += 1
            else:
                    new_word += "с"

        elif symbol == "t":
            new_word += "т"

        elif symbol == "u":
            new_word += "у"

        elif symbol == "f":
            new_word += "ф"

        elif symbol == "c":
            if (i + 1) < lenght and word[i + 1] == "h":
                new_word += "ч"
                i += 1
            else:
                new_word += "ц"

        i += 1
    return(new_word)

# %%
df_train_len = len(df_train)
s = time.perf_counter()
for j in range(m, df_train_len + m):
    if type(df_train["tokens"][j]) != float:
        train_without_translit = df_train["tokens"][j].split()
        ll = len(train_without_translit)
        for i in range(0, ll, 2):
            # print(type(train_without_translit[i][0]))
            if 97 <= ord(train_without_translit[i][0]) <= 122:
                textBlb = TextBlob(train_without_translit[i])
                textCorrected = textBlb.correct()
                if textCorrected == textBlb:
                    pass
                else:
                    train_without_translit[i] = reverse_translit_2(train_without_translit[i])
            # print(i)
            current_word = train_without_translit[i]
            current_len = len(current_word)
            current_del = int(np.floor(current_len * 0.2))
            # print(current_word, ' ', current_len, ' ', current_del)
            if current_del >= 1:
                train_without_translit[i] = train_without_translit[i][0: - current_del]
        df_train['tokens'][j] = train_without_translit
    print(j, ' ', (time.perf_counter() - s) / 60)
    print(train_without_translit[i])
# Out:
# ждат
# 1363   72.10940113755
# left
# 1364   72.42097646114986
# промсвязьба
# 1365   73.66390293171656
# izvestn
# 1366   74.23088125513326
# плати
# 1367   74.44043366749987
# konfu
# 1368   74.79886536165007
# banner
# 1369   75.17323152398325
# izmenyae
# 1370   75.53157368485009
# села
# 1371   76.46594503753332
# андрои
# 1372   76.48303317064989
# бойкин
# 1373   77.10475087000002
# rober
# 1374   77.15392714255007
# оплатит
# 1375   77.34012198748327
# decisio
# 1376   77.63581358224995
# трудоустройс
# 1377   77.63582548441664
# календар
# 1378   77.87162889316666
# ебли
# 1379   79.46071752386669
# зени
# 1380   80.09087004620002
# пионерлаге
# 1381   80.09322081954997
# хороше
# 1382   80.17373498998337
# тайны
# 1383   80.36481874083341
# banner
# 1384   80.77937405196657
# rep

# %%
df_train.to_csv("Source/df_train_short_1200_1400.csv", index = False)

# %%
train_ex = pd.read_csv("Source/df_train_short_1200_1400.csv")

# %%
train_ex
# Out:
#      Unnamed: 0  CLIENT_ID  RETRO_DT  \
# 0          1200  811039501  20210923
# 1          1201    1911897  20210923
# 2          1202    6009526  20201015
# 3          1203    1808234  20210919
# 4          1204    1394729  20210618
# ..          ...        ...       ...
# 195        1395  815542861  20220106
# 196        1396    1748900  20210812
# 197        1397  223652821  20211207
# 198        1398    1883367  20210917
# 199        1399  814051331  20211203
#
#                                                 tokens  \
# 0    ['выплат', '1', 'code', '5', 'отказо', '2', 'f...
# 1    ['мобильны', '1', 'code', '1', 'forge', '1', '...
# 2    ['отличны', '2', 'prikolny', '2', 'рождени', '...
# 3    ['реальн', '1', 'подскажи', '1', 'карт', '1', ...
# 4    ['manikyur', '1', 'боррое', '1', 'служб', '1',...
# ..                                                 ...
# 195  ['тосо', '2', 'code', '3', 'отказо', '1', 'тов...
# 196  ['креди', '2', 'golf', '2', 'экспрес', '2', 'к...
# 197  ['biografi', '1', 'опубликова', '1', 'сторон',...
# 198  ['креди', '10', 'code', '1', 'жизне', '8', 'ба...
# 199  ['утеплит', '1', 'серо', '1', 'куртк', '1', 'д...
#
#                                            urls_hashed
# 0    f333f7c2bc75e8eac24efe906c54f1be 2 fe0bebff999...
# 1    f333f7c2bc75e8eac24efe906c54f1be 1 aee71c8d18d...
# 2    8eb7aebfee7aee0c42e45f8ac770339b 2 0028c3b6811...
# 3    0028c3b68113a97ccf75351d44d647cd 2 315811907eb...
# 4    22cf49dce7ebecb0540ea775e09b6591 1 a51fa12f9f4...
# ..                                                 ...
# 195  1efc71403bf1b9917eb4ee327dd530ed 2 28750ed66a4...
# 196  84f58fb953a917a73099a954fa8136dc 2 4e3e482c0e1...
# 197  67a554325992d2f87c00fcb69f32052c 2 c3291e65ec1...
# 198  346312e420798e35cd6d136e86a6e204 1 342e68db9f0...
# 199  f333f7c2bc75e8eac24efe906c54f1be 1 aee71c8d18d...
#
# [200 rows x 5 columns]
